# %% [markdown]
# <a href="https://colab.research.google.com/github/I-AM-PRASHANT-VERMA/Almabetter-voyage-analytics-mlops/blob/main/EDA_Notebook_/flight_and_hotel_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Voyage Analytics: Exploratory Data Analysis of Travel Pricing and Customer Behavior ✈️📊

# %% [markdown]
# ##### **Project Type**    - EDA

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on performing an in-depth Exploratory Data Analysis (EDA) on a travel-based dataset consisting of users, flights, and hotels ✈️🏨👥. The main objective of this analysis is to understand patterns, relationships, and trends within the data that can help businesses make better decisions related to pricing, customer behavior, and service optimization 📊.
#
# The dataset is divided into three key parts. The Users dataset provides demographic information such as age and gender, which helps in understanding who the customers are. The Flights dataset includes details like flight routes, distance, type of flight, and price, which are essential for analyzing pricing strategies. The Hotels dataset contains information about hotel location, number of days stayed, price per day, and total booking cost, which helps in understanding accommodation patterns. By analyzing these datasets individually and in combination, we can get a complete picture of the travel journey from booking a flight to staying at a hotel 🌍.
#
# A total of 37 visualizations were created, including univariate, bivariate, and multivariate charts, to explore the data from different perspectives. Univariate analysis helped in understanding the distribution of key variables such as flight price, user age, and hotel price per day. Bivariate analysis was used to study relationships like distance vs flight price and hotel stay duration vs total cost. Multivariate analysis provided deeper insights by combining multiple variables, such as analyzing how flight type and distance together impact pricing 📈.
#
# From the analysis, several important insights were identified. Flight prices were found to increase with distance, confirming a strong positive relationship between these variables. Flight type also plays a major role in pricing, with first class being the most expensive and economy being the most affordable. Hotel pricing showed clear clustering, indicating fixed pricing tiers such as budget, mid-range, and premium categories 🏨💰.
#
# User behavior analysis revealed that middle-aged users, especially the 36–50 age group, form the largest user segment. The 30–50 group is also a key active segment, so it is useful for customer targeting. Additionally, the gender distribution was found to be balanced, suggesting that the platform serves a diverse user base and does not rely heavily on one demographic group 👥.
#
# Location-based analysis showed that certain cities generate significantly higher hotel revenue compared to others, highlighting the importance of geography in travel demand. Similarly, time-based analysis revealed slight seasonal variations in flight pricing, indicating that demand fluctuates across different months 📅.
#
# Another key finding was that total travel cost, which includes both flight and hotel expenses, increases with distance and duration of stay. This shows that longer trips tend to generate higher revenue, making long-distance travelers a valuable customer segment ✨.
#
# Overall, this EDA project provides a strong foundation for understanding travel data. It highlights how pricing, customer demographics, location, and travel behavior are interconnected. These insights can help businesses optimize pricing strategies, identify high-value customers, and improve service offerings. By using data-driven analysis, companies can make more informed decisions, enhance customer experience, and create more effective business strategies 🚀.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/I-AM-PRASHANT-VERMA/Almabetter-voyage-analytics-mlops/tree/main

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The travel and tourism industry generates large volumes of data related to users, flights, and hotels, but this data is often not fully utilized for decision-making. Businesses face challenges in understanding pricing patterns, identifying valuable customers, and analyzing how factors like distance, duration, and location impact overall travel cost ✈️🏨👥.
#
# In this project, the problem is to explore and analyze these datasets to uncover meaningful patterns and relationships. Without proper analysis, decisions may rely on assumptions, leading to inefficient pricing and missed opportunities 📊.
#
# The goal is to connect all datasets and answer key questions such as:
# * what factors influence flight pricing?
# * which customer segments are most active?
# * how does hotel pricing vary across locations?
# * how do different factors impact total travel cost?
#
# By addressing these, the project aims to convert raw data into actionable insights that support better business decisions and improved performance 🚀

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main objective of this project is to use data insights from users, flights, and hotels to improve business decisions in pricing, customer targeting, and service performance ✈️🏨👥.
#
# The analysis helps understand how flight prices depend on distance, type, and time, allowing better and more competitive pricing strategies 💰. It also identifies key customer groups, especially the most active age segments, enabling more focused marketing and personalized offers 🎯.
#
# By analyzing hotel data, the business can understand which locations generate higher revenue and where improvements are needed, supporting better resource allocation 🏨🌍. Additionally, combining flight and hotel data gives a clear view of total travel cost, helping create bundled offers that increase overall customer spending ✨.
#
# Seasonal patterns in pricing also allow businesses to adjust strategies during peak and low-demand periods 📅.
#
# Overall, the objective is to move towards data-driven decision-making to increase revenue, improve customer experience, and optimize business performance 🚀.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many meaningful charts as needed. Make sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Visualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Cell No - 1
# Import Libraries


import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Cell No - 2
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset Loading

# %%
# Cell No - 3
# Load Dataset

users = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/# specialization projects/1st project Voyage Analytics: Integrating MLOps in Travel/dataset flight hotel users/users.csv')
flights = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/# specialization projects/1st project Voyage Analytics: Integrating MLOps in Travel/dataset flight hotel users/flights.csv')
hotels = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/# specialization projects/1st project Voyage Analytics: Integrating MLOps in Travel/dataset flight hotel users/hotels.csv')

# Confirm loading
print("Datasets loaded successfully")
# Out:
# Datasets loaded successfully

# %% [markdown]
# ### Dataset First View

# %%
# Cell No - 4
# Dataset First Look

print("USERS DATASET")
display(users.head())

print("FLIGHTS DATASET")
display(flights.head())

print("HOTELS DATASET")
display(hotels.head())
# Out:
# USERS DATASET
#    code company             name  gender  age
# 0     0    4You        Roy Braun    male   21
# 1     1    4You   Joseph Holsten    male   37
# 2     2    4You    Wilma Mcinnis  female   48
# 3     3    4You     Paula Daniel  female   23
# 4     4    4You  Patricia Carson  female   44
# FLIGHTS DATASET
#    travelCode  userCode                from                  to  flightType  \
# 0           0         0         Recife (PE)  Florianopolis (SC)  firstClass
# 1           0         0  Florianopolis (SC)         Recife (PE)  firstClass
# 2           1         0       Brasilia (DF)  Florianopolis (SC)  firstClass
# 3           1         0  Florianopolis (SC)       Brasilia (DF)  firstClass
# 4           2         0        Aracaju (SE)       Salvador (BH)  firstClass
#
#      price  time  distance       agency        date
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019
# 1  1292.29  1.76    676.53  FlyingDrops  09/30/2019
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Cell No - 5
# Rows and Columns count

print("Users Shape:", users.shape)
print("Flights Shape:", flights.shape)
print("Hotels Shape:", hotels.shape)

print("\nUsers Rows:", users.shape[0], "Columns:", users.shape[1])
print("Flights Rows:", flights.shape[0], "Columns:", flights.shape[1])
print("Hotels Rows:", hotels.shape[0], "Columns:", hotels.shape[1])
# Out:
# Users Shape: (1340, 5)
# Flights Shape: (271888, 10)
# Hotels Shape: (40552, 8)
#
# Users Rows: 1340 Columns: 5
# Flights Rows: 271888 Columns: 10
# Hotels Rows: 40552 Columns: 8

# %% [markdown]
# ### Dataset Information

# %%
# Cell No - 6
# Dataset Information

print("USERS DATASET INFO")
users.info()

print("\nFLIGHTS DATASET INFO")
flights.info()

print("\nHOTELS DATASET INFO")
hotels.info()
# Out:
# USERS DATASET INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   code     1340 non-null   int64
#  1   company  1340 non-null   object
#  2   name     1340 non-null   object
#  3   gender   1340 non-null   object
#  4   age      1340 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 52.5+ KB
#
# FLIGHTS DATASET INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271888 entries, 0 to 271887
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   travelCode  271888 non-null  int64
#  1   userCode    271888 non-null  int64
#  2   from        271888 non-null  object
#  3   to          271888 non-null  object
#  4   flightType  271888 non-null  object
#  5   price       271888 non-null  float64
#  6   time        271888 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Cell No - 7
# Checking duplicate values

print("Users Duplicate Count:", users.duplicated().sum())
print("Flights Duplicate Count:", flights.duplicated().sum())
print("Hotels Duplicate Count:", hotels.duplicated().sum())
# Out:
# Users Duplicate Count: 0
# Flights Duplicate Count: 0
# Hotels Duplicate Count: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Cell No - 8
# Missing Values/Null Values Count

print("Users Missing Values:\n", users.isnull().sum())
print("\nFlights Missing Values:\n", flights.isnull().sum())
print("\nHotels Missing Values:\n", hotels.isnull().sum())
# Out:
# Users Missing Values:
#  code       0
# company    0
# name       0
# gender     0
# age        0
# dtype: int64
#
# Flights Missing Values:
#  travelCode    0
# userCode      0
# from          0
# to            0
# flightType    0
# price         0
# time          0
# distance      0
# agency        0
# date          0
# dtype: int64
#
# Hotels Missing Values:
#  travelCode    0
# userCode      0
# name          0
# place         0
# days          0
# price         0
# total         0
# date          0
# dtype: int64

# %%
# Cell No - 9
# Visualizing the missing values

plt.figure(figsize=(15,5))
sns.heatmap(users.isnull(), cbar=False)
plt.title("Users Missing Values Heatmap")
plt.show()

plt.figure(figsize=(15,5))
sns.heatmap(flights.isnull(), cbar=False)
plt.title("Flights Missing Values Heatmap")
plt.show()

plt.figure(figsize=(15,5))
sns.heatmap(hotels.isnull(), cbar=False)
plt.title("Hotels Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Users dataset:
#
# * total 1340 rows and 5 columns
# * contains user demographic data
# * features include company, name, gender, age
# * both categorical and numerical features are present
# * no missing values → clean dataset
# * no duplicate records → reliable data
# * useful for gender classification model
# * age is an important feature to understand user behavior
#
# Flights dataset:
#
# * total 271888 rows and 10 columns
# * main dataset for flight travel data
# * features include from, to, flightType, price, time, distance, agency, date
# * both categorical and numerical features present
# * no missing values → easy preprocessing
# * no duplicate values → clean dataset
# * price is the target variable for regression
# * distance and time are strong predictors of price
# * route (from → to) is important for demand patterns
# * date can be used to extract trends and seasonality
#
# Hotels dataset:
#
# * total 40552 rows and 8 columns
# * contains hotel booking data
# * features include name, place, days, price, total, date
# * total is a derived feature (price × days)
# * no missing values → clean dataset
# * no duplicate values
# * useful for building recommendation system
# * helps understand user stay patterns
#
# Overall understanding:
#
# * datasets are connected using userCode and travelCode
#
# * users → demographic data
#
# * flights → price prediction
#
# * hotels → recommendation system
#
# * data is completely clean (no nulls, no duplicates) → ready for eda
# * overall dataset is production-ready without heavy preprocessing

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Cell No - 10
# Dataset Columns

print("Users Dataset Columns:\n", users.columns)
print("\nFlights Dataset Columns:\n", flights.columns)
print("\nHotels Dataset Columns:\n", hotels.columns)
# Out:
# Users Dataset Columns:
#  Index(['code', 'company', 'name', 'gender', 'age'], dtype='object')
#
# Flights Dataset Columns:
#  Index(['travelCode', 'userCode', 'from', 'to', 'flightType', 'price', 'time',
#        'distance', 'agency', 'date'],
#       dtype='object')
#
# Hotels Dataset Columns:
#  Index(['travelCode', 'userCode', 'name', 'place', 'days', 'price', 'total',
#        'date'],
#       dtype='object')

# %%
# Cell No - 11
# Dataset Describe

print("Users Dataset Describe:\n")
display(users.describe())

print("\nFlights Dataset Describe:\n")
display(flights.describe())

print("\nHotels Dataset Describe:\n")
display(hotels.describe())
# Out:
# Users Dataset Describe:
#               code          age
# count  1340.000000  1340.000000
# mean    669.500000    42.742537
# std     386.968991    12.869779
# min       0.000000    21.000000
# 25%     334.750000    32.000000
# 50%     669.500000    42.000000
# 75%    1004.250000    54.000000
# max    1339.000000    65.000000
# Flights Dataset Describe:
#           travelCode       userCode         price           time  \
# count  271888.000000  271888.000000  271888.00000  271888.000000
# mean    67971.500000     667.505495     957.37503       1.421147
# std     39243.724665     389.523127     362.31189       0.542541
# min         0.000000       0.000000     301.51000       0.440000
# 25%     33985.750000     326.000000     672.66000       1.040000
# 50%     67971.500000     659.000000     904.00000       1.460000
# 75%    101957.250000    1011.000000    1222.24000       1.760000
# max    135943.000000    1339.000000    1754.17000       2.440000
#
#             distance
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Users dataset:
#
# * total 1340 users
# * age range: 21 to 65 → dataset covers young to older adults
# * average age ≈ 43 → middle-aged users dominate
# * 50% users age between 32 and 54 → core customer segment
# * userCode covers the full user range → all users are represented in travel records
#
# Flights dataset:
#
# * total 271888 records → very large dataset (good for model training)
# * price range: 301 to 1754 → wide variation (good for regression learning)
# * average price ≈ 957 → mid-range pricing dominant
# * distance range: 168 to 937 → mix of short and long flights
# * time range: 0.44 to 2.44 hours → mostly short-haul flights
# * strong pattern: higher distance → higher price
# * 50% flights price between 672 and 1222 → stable pricing zone
# * userCode spread from 0–1339 → travel records cover all users
#
# Hotels dataset:
#
# * total 40552 bookings → medium-sized dataset
# * days range: 1 to 4 → mostly short stays
# * average stay ≈ 2.5 days → typical short trips
# * price per day: 60 to 313 → budget to premium mix
# * total cost: 60 to 1252 → depends on stay duration
# * 50% bookings total between 247 and 742 → mid-range spending
# * clear relationship: days ↑ → total ↑
#
# Overall understanding:
#
# * business insight:
#   most users are middle-aged → target segment
#   flights are mostly short distance → regional travel focus
#   hotel stays are short → quick trip pattern
#
# * modeling advantage:
#   wide variation in price, distance, time → strong learning signals
#   clean + large dataset → high model performance expected
#
# * overall data is structured, balanced, and ready for EDA

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Cell No - 12
# Check Unique Values for each variable.


for col in users.columns:
    print(f"Users - {col}:", users[col].nunique())

print("\n------------------------\n")

for col in flights.columns:
    print(f"Flights - {col}:", flights[col].nunique())

print("\n------------------------\n")

for col in hotels.columns:
    print(f"Hotels - {col}:", hotels[col].nunique())
# Out:
# Users - code: 1340
# Users - company: 5
# Users - name: 1338
# Users - gender: 3
# Users - age: 45
#
# ------------------------
#
# Flights - travelCode: 135944
# Flights - userCode: 1335
# Flights - from: 9
# Flights - to: 9
# Flights - flightType: 3
# Flights - price: 490
# Flights - time: 33
# Flights - distance: 35
# Flights - agency: 3
# Flights - date: 999
#
# ------------------------
#
# Hotels - travelCode: 40552
# Hotels - userCode: 1310
# Hotels - name: 9
# Hotels - place: 9
# Hotels - days: 4
# Hotels - price: 9
# Hotels - total: 36
# Hotels - date: 199

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Cell No - 13
# Write your code to make your dataset analysis ready.

# Create copies (safe practice)
users_df = users.copy()
flights_df = flights.copy()
hotels_df = hotels.copy()

# Convert date columns (ONLY where present)
flights_df['date'] = pd.to_datetime(flights_df['date'])
hotels_df['date'] = pd.to_datetime(hotels_df['date'])

# Check again for safety
print("Users Missing:\n", users_df.isnull().sum())
print("\nFlights Missing:\n", flights_df.isnull().sum())
print("\nHotels Missing:\n", hotels_df.isnull().sum())

# No missing values → no imputation needed
# No duplicates already → no removal needed

# Feature Engineering on flights dataset (correct dataset)

# Flight duration category
flights_df['time_category'] = pd.cut(
    flights_df['time'],
    bins=[0, 1, 2, 3],
    labels=['short', 'medium', 'long']
)

# Distance category
flights_df['distance_category'] = pd.cut(
    flights_df['distance'],
    bins=[0, 400, 700, 1000],
    labels=['short', 'medium', 'long']
)

# Price category (for segmentation understanding)
flights_df['price_category'] = pd.qcut(
    flights_df['price'],
    3,
    labels=['low', 'medium', 'high']
)

# Route feature (EDA purpose)
flights_df['route'] = flights_df['from'] + " → " + flights_df['to']

# Price efficiency
flights_df['price_per_km'] = flights_df['price'] / flights_df['distance']

# Extract date features
flights_df['year'] = flights_df['date'].dt.year
flights_df['month'] = flights_df['date'].dt.month
flights_df['day'] = flights_df['date'].dt.day

# Final check
flights_df.head()
# Out:
# Users Missing:
#  code       0
# company    0
# name       0
# gender     0
# age        0
# dtype: int64
#
# Flights Missing:
#  travelCode    0
# userCode      0
# from          0
# to            0
# flightType    0
# price         0
# time          0
# distance      0
# agency        0
# date          0
# dtype: int64
#
# Hotels Missing:
#  travelCode    0
# userCode      0
# name          0
# place         0
# days          0
# price         0
# total         0
# date          0
# dtype: int64
#    travelCode  userCode                from                  to  flightType  \
# 0           0         0         Recife (PE)  Florianopolis (SC)  firstClass
# 1           0         0  Florianopolis (SC)         Recife (PE)  firstClass
# 2           1         0       Brasilia (DF)  Florianopolis (SC)  firstClass
# 3           1         0  Florianopolis (SC)       Brasilia (DF)  firstClass
# 4           2         0        Aracaju (SE)       Salvador (BH)  firstClass
#
# ...

# %%
# Cell No - 14
users_df.head()
# Out:
#    code company             name  gender  age
# 0     0    4You        Roy Braun    male   21
# 1     1    4You   Joseph Holsten    male   37
# 2     2    4You    Wilma Mcinnis  female   48
# 3     3    4You     Paula Daniel  female   23
# 4     4    4You  Patricia Carson  female   44

# %%
# Cell No - 15
hotels_df.head()
# Out:
#    travelCode  userCode     name               place  days   price    total  \
# 0           0         0  Hotel A  Florianopolis (SC)     4  313.02  1252.08
# 1           2         0  Hotel K       Salvador (BH)     2  263.41   526.82
# 2           7         0  Hotel K       Salvador (BH)     3  263.41   790.23
# 3          11         0  Hotel K       Salvador (BH)     4  263.41  1053.64
# 4          13         0  Hotel A  Florianopolis (SC)     1  313.02   313.02
#
#         date
# 0 2019-09-26
# 1 2019-10-10
# 2 2019-11-14
# 3 2019-12-12
# 4 2019-12-26

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Data manipulations performed:
#
# * made copies of all datasets so original data stays safe
# * converted date columns in flights and hotels to datetime for proper time analysis
# * checked missing values and duplicates → nothing found, so no cleaning needed
# * focused feature engineering on flights dataset since it is main dataset for prediction
# * created time_category to group flights into short, medium, long durations
# * created distance_category to group flights based on travel distance
# * created price_category using quantiles to divide prices into low, medium, high
# * created route feature by combining from and to columns for route-level analysis
# * created price_per_km to understand cost efficiency of flights
# * extracted year, month, day from date to analyze trends over time
#
# Insights found:
#
# * dataset is already clean and structured, so preprocessing effort is very low
# * flights dataset is large, so model training will be strong and reliable
# * flight prices vary a lot (around 300 to 1700), so model will learn good patterns
# * flights are mostly short-duration, with distance varying across routes → regional travel patterns are visible
# * price increases with distance and time → strong relationship
# * price_per_km gives better understanding of which routes are expensive or cheap
# * most users are middle-aged (around 30–50), so this is main target group
# * hotel stays are usually short (1–4 days), so trips are mostly short-term
# * total hotel cost depends directly on number of days → simple pattern
# * route feature helps in understanding demand and pricing between cities
# * date features will help in finding monthly or seasonal trends

# %% [markdown]
# ## ***4. Data Visualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# **UNIVARIATE**

# %% [markdown]
# #### Chart - 1

# %%
# Cell No - 16
# Chart - 1: Flight Price Distribution
plt.figure(figsize=(8,5))
sns.histplot(flights['price'], bins=30, kde=True, color='blue')
plt.title("Flight Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a histogram with KDE line is used because flight price is a continuous variable and we need to understand its distribution clearly 📊
# * it helps in visualizing frequency of prices across different ranges instead of just averages
# * the KDE line adds smooth trend understanding, making patterns like peaks and clusters more visible ✈️
# * this chart is ideal to detect skewness, multiple pricing segments, and outliers in one view

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * flight prices are spread widely from around 300 to 1800, showing high variability ✈️
# * most prices are concentrated between 600 and 1000, indicating this is the most common booking range 💰
# * multiple peaks are visible, suggesting different pricing tiers like economic, premium, and first class 📊
# * there is a noticeable right skew, meaning higher price values exist but with lower frequency 📉
# * some extreme high-price values (above 1500) indicate premium or luxury travel segments

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify the most common pricing range (600–1000), useful for pricing strategy 🎯
# * businesses can optimize offers and discounts in this range to maximize conversions 💼
# * presence of multiple peaks allows segmentation-based pricing for different customer groups ✨
# * high-price segment has lower frequency, so pricing should be supported by clear premium value ⚠️
# * extreme high prices can negatively impact bookings if not supported with premium experience, leading to potential revenue loss 🚨

# %% [markdown]
# #### Chart - 2

# %%
# Cell No - 17
# Chart - 2: Average Price by Flight Type
plt.figure(figsize=(8,5))
sns.barplot(data=flights, x='flightType', y='price', palette='viridis')
plt.title("Average Price by Flight Type")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing average prices across discrete categories (flight types) 📊
# * it clearly shows differences between first class, economic, and premium in a simple visual way
# * bar height makes it easy to identify which category is highest or lowest instantly ✈️
# * this chart is ideal for category-wise comparison without confusion

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * first class flights have the highest average price, around 1180, showing premium positioning 💰
# * economic flights have the lowest average price, around 650, making them the most affordable option ✈️
# * premium flights fall in between, around 900, acting as a mid-tier offering 📊
# * clear price gap exists between all three categories, showing structured pricing strategy

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps in clear customer segmentation based on budget and service preference 🎯
# * businesses can target different user groups with tailored pricing strategies 💼
# * economic segment can drive volume, while first class drives higher profit margins ✨
# * large price gap between economic and first class may discourage mid-range customers ⚠️
# * if premium category is not well positioned, customers may shift directly to cheaper economic options, reducing revenue potential 🚨

# %% [markdown]
# #### Chart - 3

# %%
# Cell No - 18
# Chart - 3: Agencies by Average Price
agency_price = flights.groupby('agency')['price'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,5))
agency_price.plot(kind='bar', color='purple')
plt.title("Agencies by Avg Price")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing average prices across different flight agencies 📊
# * it clearly shows price differences between agencies in a straightforward way
# * category-wise comparison becomes easy as each agency is represented separately ✈️
# * this chart is ideal for identifying which agency is charging higher or lower on average

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * FlyingDrops has the highest average price, around 1190, indicating premium pricing 💰
# * Rainbow and CloudFy have similar average prices, around 920, showing competitive pricing 📊
# * there is a clear gap between FlyingDrops and the other two agencies ✈️
# * Rainbow and CloudFy seem to be targeting similar customer segments

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify pricing positioning of each agency in the market 🎯
# * businesses can benchmark their pricing strategy against competitors 💼
# * FlyingDrops can focus on premium services to justify higher pricing ✨
# * Rainbow and CloudFy may face strong competition due to similar pricing, leading to price wars ⚠️
# * if FlyingDrops pricing is too high without added value, it may lose customers to cheaper competitors 🚨

# %% [markdown]
# #### Chart - 4

# %%
# Cell No - 19
# Chart - 4: Agencies by Flight Count
agency_count = flights['agency'].value_counts()

plt.figure(figsize=(10,5))
agency_count.plot(kind='bar', color='green')
plt.title("Agencies by Flight Count")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing flight counts across different agencies 📊
# * it clearly shows which agency has more or fewer flights in a simple visual format
# * bar heights make it easy to identify dominance or gaps between agencies ✈️
# * this chart is ideal for volume comparison and market share understanding

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Rainbow and CloudFy have almost equal and very high flight counts, around 117000 each ✈️
# * FlyingDrops has significantly lower flight count, around 39000 📉
# * Rainbow and CloudFy dominate the market in terms of volume 📊
# * FlyingDrops operates at a much smaller scale compared to competitors

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify market leaders based on flight volume 🎯
# * Rainbow and CloudFy can leverage scale advantage to attract more customers 💼
# * FlyingDrops can focus on niche or premium segment instead of competing on volume ✨
# * low flight count for FlyingDrops may lead to lower market visibility and reduced customer reach ⚠️
# * imbalance in market share may create strong competition pressure on smaller agencies 🚨

# %% [markdown]
# #### Chart - 5

# %%
# Cell No - 20
# Chart - 5: Top 10 Routes by Flight Count
flights['route'] = flights['from'] + " → " + flights['to']
top_routes_count = flights['route'].value_counts().head(10)

plt.figure(figsize=(10,5))
top_routes_count.plot(kind='bar', color='orange')
plt.title("Top 10 Routes by Flight Count")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing flight counts across multiple routes 📊
# * it helps in identifying which routes are most frequently used in a clear way
# * bar lengths make it easy to rank routes from highest to lowest demand ✈️
# * this chart is ideal for categorical comparison where each route is a separate entity

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * routes involving Florianopolis (SC) appear most frequently, showing it is a major hub ✈️
# * top routes like Florianopolis ↔ Aracaju and Aracaju ↔ Florianopolis have the highest counts 📊
# * demand is quite evenly distributed among top routes, with no extreme outlier 💰
# * routes connecting major cities like Brasilia, Recife, and Sao Paulo also show strong demand

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify high-demand routes where airlines can increase frequency 🎯
# * businesses can optimize pricing and seat allocation on popular routes 💼
# * Florianopolis can be treated as a strategic hub for expansion ✨
# * similar demand across routes may increase competition, reducing pricing power ⚠️
# * if supply increases too much on same routes, it may lead to reduced profitability due to competition 🚨

# %% [markdown]
# #### Chart - 6

# %%
# Cell No - 21
# Chart - 6: Top 10 Routes by Average Price
top_routes_price = flights.groupby('route')['price'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_routes_price.plot(kind='bar', color='red')
plt.title("Top 10 Routes by Avg Price")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing average prices across different routes 📊
# * it clearly highlights which routes are more expensive than others in a simple way
# * bar heights make ranking of routes based on price very easy to understand ✈️
# * this chart is ideal for categorical comparison where each route has a distinct average value

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Sao Paulo → Florianopolis route has the highest average price, close to 1380 💰
# * most top routes have very similar average prices between 1340 and 1380 📊
# * price variation across top routes is very small, showing consistent pricing strategy ✈️
# * Brasilia → Florianopolis has relatively lower price among top routes, around 1260 📉

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * consistent pricing across routes helps maintain customer trust and predictability 🎯
# * businesses can standardize pricing strategy across major routes 💼
# * high-priced routes like Sao Paulo → Florianopolis can be targeted for premium services ✨
# * low price variation may reduce competitive advantage, making it hard to differentiate ⚠️
# * if all routes are priced similarly, customers may choose based on convenience instead of brand, reducing loyalty 🚨

# %% [markdown]
# #### Chart - 7

# %%
# Cell No - 22
# Chart - 7: Distance vs Price
plt.figure(figsize=(8,5))
sns.scatterplot(data=flights, x='distance', y='price', color='blue')
plt.title("Distance vs Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a scatter plot is used because we want to analyze relationship between two continuous variables: distance and price 📊
# * it helps in identifying correlation patterns (positive, negative, or no relation)
# * each point represents a flight, making it easy to see spread and clusters ✈️
# * this chart is ideal for detecting trends, outliers, and variability in pricing

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * there is a clear positive relationship between distance and price, meaning longer flights tend to cost more ✈️
# * shorter distances (below 300) mostly have lower prices between 300–700 💰
# * mid-range distances (400–700) show wide price variation, indicating other factors also affect pricing 📊
# * long distances (above 800) generally have higher prices, often above 1200 📈
# * some outliers exist where similar distances have very different prices, showing inconsistency

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps in building pricing models based on distance, improving prediction accuracy 🎯
# * businesses can standardize pricing rules for different distance ranges 💼
# * variability in mid-range distances suggests opportunity for optimization and better pricing control ✨
# * inconsistent pricing for similar distances may confuse customers and reduce trust ⚠️
# * if pricing is not aligned with distance properly, it may lead to customer dissatisfaction and lost bookings 🚨

# %% [markdown]
# #### Chart - 8

# %%
# Cell No - 23
# Chart - 8: Time vs Price (with trendline)
plt.figure(figsize=(8,5))
sns.regplot(data=flights, x='time', y='price', scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title("Time vs Price with Trendline")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a scatter plot with trendline is used because we want to analyze relationship between time and price 📊
# * scatter points show actual data distribution while the trendline shows overall direction clearly
# * it helps in identifying correlation and strength of relationship ✈️
# * this chart is ideal to understand how flight duration impacts pricing in a clear visual way

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * there is a clear positive trend, meaning longer flight duration generally leads to higher prices ✈️
# * shorter flights (below 1 hour) mostly have lower prices between 300–700 💰
# * mid-duration flights (1–2 hours) show wide price variation, indicating influence of other factors 📊
# * longer flights (above 2 hours) mostly fall in higher price range above 1200 📈
# * some variation exists even for same duration, showing pricing is not only dependent on time

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps improve pricing models by including time as an important feature 🎯
# * businesses can standardize pricing bands based on flight duration 💼
# * variation in mid-duration flights gives opportunity to optimize pricing strategy ✨
# * inconsistent pricing for similar duration flights may confuse customers ⚠️
# * if pricing is not aligned properly with duration, it may reduce customer trust and booking conversion 🚨

# %% [markdown]
# #### Chart - 9

# %%
# Cell No - 24
# Chart - 9: Price per KM Distribution
flights['price_per_km'] = flights['price'] / flights['distance']

plt.figure(figsize=(8,5))
sns.histplot(flights['price_per_km'], bins=30, kde=True, color='teal')
plt.title("Price per KM Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a histogram with KDE line is used because price per km is a continuous variable and we need to understand its distribution 📊
# * it helps in identifying how pricing efficiency varies across flights
# * the KDE line makes it easier to see overall trends and peaks clearly ✈️
# * this chart is ideal for detecting pricing patterns, clusters, and outliers in cost efficiency

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * most price per km values are concentrated between 1.2 and 2.2, showing common pricing efficiency range 💰
# * there is a peak around 1.8–2.0, indicating most flights follow similar cost structure 📊
# * some higher values (above 3.0) exist, showing inefficient or expensive routes 📉
# * distribution is right-skewed, meaning few routes are significantly overpriced compared to majority ✈️

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify standard cost efficiency range for pricing optimization 🎯
# * businesses can benchmark routes and reduce high price per km values 💼
# * consistent pricing cluster indicates stable pricing strategy ✨
# * high price per km routes may reduce customer satisfaction and competitiveness ⚠️
# * overpriced routes can lead to lower bookings and revenue loss if not corrected 🚨

# %% [markdown]
# **MULTIVARIATE**

# %% [markdown]
# #### Chart - 10

# %%
# Cell No - 25
# Chart - 10: Monthly Average Flight Price Trend
flights['date'] = pd.to_datetime(flights['date'])
flights['month'] = flights['date'].dt.month

monthly_price = flights.groupby('month')['price'].mean()

plt.figure(figsize=(8,5))
monthly_price.plot(marker='o')
plt.title("Monthly Avg Flight Price Trend")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a line chart is used because we are analyzing price trends over time (monthly) 📊
# * it helps in showing how prices change sequentially across months
# * the continuous line makes it easy to identify upward and downward trends ✈️
# * this chart is ideal for time-series analysis and trend detection

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * prices increase from month 1 to around month 6, showing a rising trend ✈️
# * peak average prices occur around months 5 and 6, showing slightly higher pricing in that period 💰
# * after month 6, prices gradually decline until month 9 📉
# * slight recovery is seen towards months 10–11, followed by small fluctuation 📊
# * overall variation is small, showing stable pricing throughout the year

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify months where average pricing is slightly higher 🎯
# * businesses can plan promotions during low-price months to boost bookings 💼
# * stable pricing trend helps maintain customer trust ✨
# * slight drop after peak months may indicate pricing softness, which should be reviewed with booking volume ⚠️
# * pricing decisions should be checked together with booking volume to avoid wrong assumptions 🚨

# %% [markdown]
# #### Chart - 11

# %%
# Cell No - 26
# Chart - 11: Monthly Flight Count Trend
monthly_count = flights.groupby('month').size()

plt.figure(figsize=(8,5))
monthly_count.plot(marker='o', color='black')
plt.title("Monthly Flight Count Trend")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a line chart is used because we are analyzing flight count trends over time (monthly) 📊
# * it helps in understanding how demand changes across months in a continuous flow
# * the line structure makes it easy to spot peaks, drops, and seasonal patterns ✈️
# * this chart is ideal for time-series analysis and demand fluctuation tracking

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * flight count starts high in month 1 and drops gradually till month 6 📉
# * lowest demand is around month 8, showing a clear dip in bookings ✈️
# * after month 9, there is a sharp increase, peaking at month 10 📈
# * months 10–12 maintain relatively high flight counts, indicating strong demand 📊
# * clear seasonal pattern is visible with mid-year dip and year-end surge

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify peak months (10–12) where capacity and pricing can be optimized 🎯
# * businesses can prepare resources in advance for high-demand periods 💼
# * low-demand months (6–8) can be targeted with discounts and offers ✨
# * significant drop in mid-year demand may lead to revenue loss if not managed ⚠️
# * poor planning during peak months may result in missed opportunities and customer dissatisfaction 🚨

# %% [markdown]
# #### Chart - 12

# %%
# Cell No - 27
# Chart - 12: Heatmap (FlightType vs Agency vs Avg Price)
pivot = flights.pivot_table(values='price', index='flightType', columns='agency', aggfunc='mean')

plt.figure(figsize=(12,6))
sns.heatmap(pivot, cmap='viridis')
plt.title("Heatmap: FlightType vs Agency vs Avg Price")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a heatmap is used because we are comparing three variables together: flight type, agency, and average price 📊
# * it helps in identifying patterns and differences using color intensity instead of numbers
# * this chart allows quick comparison across multiple combinations at once ✈️
# * heatmap is ideal for spotting high and low pricing zones visually without complexity

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * first class flights have the highest prices across all agencies, shown by brightest colors 💰
# * economic flights are consistently the lowest priced across all agencies 📉
# * premium flights fall in the middle range, showing balanced pricing ✈️
# * FlyingDrops tends to have slightly higher prices across categories compared to others 📊
# * pricing structure is consistent across agencies with clear tier-based separation

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps businesses maintain clear pricing tiers for different customer segments 🎯
# * agencies can benchmark their pricing against competitors for each flight type 💼
# * consistent pricing structure improves customer understanding and trust ✨
# * if one agency (like FlyingDrops) is consistently higher priced, it may lose price-sensitive customers ⚠️
# * lack of differentiation in pricing strategy may reduce competitive advantage across agencies 🚨

# %% [markdown]
# #### Chart - 13

# %%
# Cell No - 28
# Chart - 13: Distance vs Price (Hue = FlightType)
plt.figure(figsize=(8,5))
sns.scatterplot(data=flights, x='distance', y='price', hue='flightType')
plt.title("Distance vs Price by Flight Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a scatter plot with category colors is used because we are comparing relationship between distance and price across different flight types 📊
# * it allows visualization of multiple groups (first class, economic, premium) in one chart clearly
# * color separation helps in identifying how pricing differs by category ✈️
# * this chart is ideal for multi-variable comparison and trend analysis together

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * all flight types show positive relationship between distance and price ✈️
# * first class flights consistently have highest prices across all distances 💰
# * economic flights are lowest priced, clearly separated from other categories 📉
# * premium flights lie in between, showing mid-tier pricing 📊
# * price gap between categories increases as distance increases, especially for first class

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps in designing pricing models specific to each flight type and distance 🎯
# * businesses can clearly segment customers based on budget and service level 💼
# * higher margins can be targeted in first class for long-distance routes ✨
# * large price gap at higher distances may discourage upgrades from economic to premium ⚠️
# * if pricing gap becomes too large, customers may stick to cheaper options, reducing revenue potential 🚨

# %% [markdown]
# #### Chart - 14

# %%
# Cell No - 29
# Chart - 14: Agency Flight Count and Avg Price
agency_price = flights.groupby('agency')['price'].mean()
agency_count = flights['agency'].value_counts()

combined = pd.concat([agency_price, agency_count], axis=1)
combined.columns = ['avg_price', 'count']
combined = combined.sort_values(by='count', ascending=False)

fig, ax1 = plt.subplots(figsize=(10,5))

ax1.bar(combined.index, combined['count'], alpha=0.6)
ax1.set_ylabel('Flight Count')

ax2 = ax1.twinx()
ax2.plot(combined.index, combined['avg_price'], color='red', marker='o')
ax2.set_ylabel('Avg Price')

plt.title("Agency Flight Count vs Avg Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a combined bar and line chart is used to compare two metrics together: flight count and average price 📊
# * bars represent volume while the line represents pricing, making dual analysis easy
# * it helps in understanding trade-off between quantity and pricing across agencies ✈️
# * this chart is ideal for comparing performance and positioning in one view

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Rainbow and CloudFy have very high and similar flight counts, around 116000+ ✈️
# * FlyingDrops has much lower flight count, around 39000 📉
# * FlyingDrops has the highest average price despite lowest volume 💰
# * Rainbow and CloudFy maintain lower prices with higher volume, showing volume-based strategy 📊

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify two different strategies: high volume low price vs low volume high price 🎯
# * Rainbow and CloudFy can focus on scale and market dominance 💼
# * FlyingDrops can focus on premium niche and higher margins ✨
# * low volume for FlyingDrops may limit growth and market share ⚠️
# * high pricing without strong value proposition may reduce customer acquisition 🚨

# %%
# Cell No - 30
# Chart - 15: Correlation Heatmap
numeric_cols = ['price', 'distance', 'time', 'price_per_km']
corr = flights[numeric_cols].corr()

plt.figure(figsize=(8,5))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a correlation heatmap is used because we want to analyze relationships between multiple numerical variables at once 📊
# * it provides strength and direction of relationships using color intensity and values
# * it helps quickly identify strong, weak, positive, and negative correlations ✈️
# * this chart is ideal for feature understanding before model building

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * price has strong positive correlation with distance and time (~0.64), meaning longer flights cost more ✈️
# * distance and time are perfectly correlated (1.0), showing they move together almost exactly 📊
# * price_per_km has weak positive correlation with price (~0.2), meaning total price is not fully dependent on efficiency 💰
# * price_per_km has negative correlation with distance and time (~-0.56), meaning longer flights are more cost efficient per km 📉

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps in selecting important features like distance and time for pricing models 🎯
# * businesses can design better pricing strategies based on strong correlations 💼
# * understanding cost efficiency (price_per_km) helps optimize route pricing ✨
# * high correlation between distance and time may cause redundancy in models ⚠️
# * ignoring multicollinearity can reduce model performance and lead to incorrect predictions 🚨

# %%
# Cell No - 31
# Chart - 16: Hotel Price Distribution
plt.figure(figsize=(8,5))
sns.histplot(hotels['price'], bins=30, kde=True, color='green')
plt.title("Hotel Price Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a histogram with KDE line is used because hotel price is a continuous variable and we need to understand its distribution 📊
# * it helps in visualizing how hotel prices are spread across different ranges
# * the KDE line highlights peaks and clusters clearly ✈️
# * this chart is ideal for identifying pricing segments and outliers in hotel pricing

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * hotel prices are spread across a wide range from around 60 to 320 💰
# * multiple peaks are visible, indicating different pricing tiers (budget, mid-range, luxury) 📊
# * a strong concentration is seen around 240–260, showing a popular pricing range ✈️
# * some higher price points (above 300) indicate premium hotel offerings 📈
# * distribution is slightly right-skewed, meaning fewer high-price hotels exist

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify the common hotel price range for pricing review 🎯
# * businesses can review mid-range pricing (240–260) as a common hotel price band 💼
# * multiple segments allow targeting different customer groups ✨
# * very high-priced hotels should clearly justify their value to customers ⚠️
# * imbalance in pricing segments may lead to missed opportunities in underrepresented ranges 🚨

# %%
# Cell No - 32
# Chart - 17: Total Spend Distribution (Hotels)
plt.figure(figsize=(8,5))
sns.histplot(hotels['total'], bins=30, kde=True, color='purple')
plt.title("Total Hotel Spend Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a histogram with KDE line is used because total hotel spend is a continuous variable and we need to understand its distribution 📊
# * it helps in visualizing how customer spending varies across different ranges
# * the KDE line highlights spending patterns and clusters clearly ✈️
# * this chart is ideal for identifying customer spending behavior and segmentation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * total hotel spend ranges widely from around 100 to 1250, showing diverse customer budgets 💰
# * multiple peaks indicate different spending groups such as low, medium, and high spenders 📊
# * a strong concentration is seen around 200–300 and 500–700 ranges ✈️
# * some high spend values (above 900) represent premium or long-stay customers 📈
# * distribution is slightly right-skewed, meaning fewer high spenders exist

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps segment customers based on spending behavior for targeted marketing 🎯
# * businesses can design packages for mid-range spenders to maximize revenue 💼
# * high spenders can be targeted with premium services and loyalty programs ✨
# * low spend concentration may reduce overall revenue if not upsold properly ⚠️
# * ignoring high-value customers may lead to missed profit opportunities 🚨

# %%
# Cell No - 33
# Chart - 18: Places by Avg Hotel Price
places_price = hotels.groupby('place')['price'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,5))
places_price.plot(kind='bar', color='orange')
plt.title("Places by Avg Hotel Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing average hotel prices across different places 📊
# * it clearly shows which locations are more expensive or affordable
# * bar height makes ranking of places very easy to understand ✈️
# * this chart is ideal for location-based comparison and pricing analysis

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Florianopolis and Recife have the highest average hotel prices, around 310+ 💰
# * Salvador, Brasilia, and Natal fall in mid-range pricing between 240–270 📊
# * Aracaju and Rio de Janeiro are relatively lower priced ✈️
# * Sao Paulo and Campo Grande have the lowest hotel prices, with Campo Grande being the cheapest 📉
# * clear pricing gap exists between top and bottom locations

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps businesses identify premium and budget locations for pricing strategy 🎯
# * high-price locations can be targeted for luxury offerings and higher margins 💼
# * low-price locations can attract budget travelers and increase volume ✨
# * large price gap between locations may affect customer choice if value is not clear ⚠️
# * expensive locations should be monitored to ensure pricing is justified by value 🚨

# %%
# Cell No - 34
# Chart - 19: Places by Total Revenue
places_total = hotels.groupby('place')['total'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
places_total.plot(kind='bar', color='red')
plt.title("Places by Total Revenue")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing total revenue across different places 📊
# * it clearly shows which locations generate more or less revenue
# * bar height makes ranking of places by revenue very easy ✈️
# * this chart is ideal for identifying top-performing and low-performing locations

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Recife generates the highest total revenue, followed by Salvador 💰
# * Natal, Brasilia, and Florianopolis also contribute strong revenue 📊
# * mid-level revenue is seen in Aracaju and Rio de Janeiro ✈️
# * Sao Paulo has relatively lower revenue despite being a major city 📉
# * Campo Grande has the lowest revenue among all locations

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify high-revenue locations for focused investment and expansion 🎯
# * businesses can prioritize Recife and Salvador for maximizing returns 💼
# * low-performing locations can be analyzed for improvement or cost reduction ✨
# * low revenue in major city like Sao Paulo may indicate underperformance ⚠️
# * ignoring low-revenue areas may lead to missed growth opportunities if potential is not explored 🚨

# %%
# Cell No - 35
# Chart - 20: Days vs Total Spend
plt.figure(figsize=(8,5))
sns.scatterplot(data=hotels, x='days', y='total', color='blue')
plt.title("Days vs Total Hotel Spend")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a scatter plot is used because we want to analyze relationship between number of days and total hotel spend 📊
# * it helps in identifying how spending increases with stay duration
# * each point represents a booking, showing real variation in spending ✈️
# * this chart is ideal for detecting trends, patterns, and outliers in spending behavior

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * there is a clear positive relationship between days and total spend, meaning longer stays lead to higher spending 💰
# * 1-day stays have lowest spending, mostly below 300 ✈️
# * 2–3 day stays show moderate spending with increasing variation 📊
# * 4-day stays have highest spending, often above 800 and even crossing 1200 📈
# * some variation exists for same number of days, indicating price differences across hotels

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps in designing pricing and discount strategies based on stay duration 🎯
# * businesses can encourage longer stays to increase total revenue 💼
# * packages for 3–4 day stays can be promoted for higher profitability ✨
# * variation in spending for same duration may confuse customers ⚠️
# * inconsistent pricing for similar stays may reduce trust and booking conversions 🚨

# %%
# Cell No - 36
# Chart - 21: Average Stay Duration by Place
places_days = hotels.groupby('place')['days'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,5))
places_days.plot(kind='bar', color='teal')
plt.title("Places by Avg Stay Duration")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing average stay duration across different places 📊
# * it clearly shows small differences between categories in a simple visual format
# * bar height makes comparison easy even when values are very close ✈️
# * this chart is ideal for category-wise comparison of average values

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * average stay duration is almost same across all places, around 2.5 days ✈️
# * no location stands out significantly in terms of longer or shorter stays 📊
# * customer behavior in terms of stay duration is consistent across cities 💰
# * very minimal variation indicates stable booking patterns

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * consistent stay duration helps in standardizing pricing and package strategies 🎯
# * businesses can create fixed-duration packages (2–3 days) across all locations 💼
# * predictable customer behavior improves planning and inventory management ✨
# * lack of variation means limited opportunity to differentiate based on stay duration ⚠️
# * uniform behavior across locations may reduce chances of location-based upselling 🚨

# %%
# Cell No - 37
# Chart - 22: Monthly Hotel Bookings Trend
hotels['date'] = pd.to_datetime(hotels['date'])
hotels['month'] = hotels['date'].dt.month

monthly_hotels = hotels.groupby('month').size()

plt.figure(figsize=(8,5))
monthly_hotels.plot(marker='o', color='black')
plt.title("Monthly Hotel Bookings Trend")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a line chart is used because we are analyzing hotel booking trends over time (monthly) 📊
# * it helps in showing how bookings change sequentially across months
# * the continuous line makes it easy to identify peaks, drops, and seasonality ✈️
# * this chart is ideal for time-series trend analysis and demand patterns

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * bookings start relatively high in month 1 and decline till around month 6 📉
# * lowest bookings occur around month 8, showing weakest demand ✈️
# * sharp increase happens after month 9, peaking at month 10 📈
# * months 10–12 maintain higher booking levels compared to mid-year 📊
# * clear seasonal trend with mid-year dip and year-end surge

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify peak booking months (10–12) for maximizing pricing and availability 🎯
# * businesses can plan promotions during low-demand months (5–8) 💼
# * better resource allocation can be done based on seasonal demand ✨
# * mid-year drop in bookings may lead to revenue loss if not addressed ⚠️
# * poor planning during peak months may result in missed revenue opportunities 🚨

# %%
# Cell No - 38
# Chart - 23: Price vs Days vs Total (Hue = Top Places)
top_places = hotels['place'].value_counts().head(5).index
filtered_hotels = hotels[hotels['place'].isin(top_places)]

plt.figure(figsize=(8,5))
sns.scatterplot(data=filtered_hotels, x='days', y='total', hue='place')
plt.title("Days vs Total Spend (Top Places)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a scatter plot with color categories is used because we are comparing relationship between days and total spend across multiple places 📊
# * it allows visualization of multiple locations in one chart clearly
# * color differentiation helps in identifying spending patterns for each place ✈️
# * this chart is ideal for multi-variable comparison and trend analysis together

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * all places show a positive relationship between days and total spend ✈️
# * Recife consistently has the highest spending across all durations 💰
# * Salvador and Natal follow mid-range spending patterns 📊
# * Rio de Janeiro and Sao Paulo have relatively lower spending for same duration 📉
# * spending gap between cities increases as number of days increases

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps in location-based pricing and package customization 🎯
# * high-spending cities like Recife can be targeted for premium offerings 💼
# * lower-spending cities can focus on budget-friendly packages ✨
# * increasing gap in spending across cities may indicate uneven revenue distribution ⚠️
# * lower-spending cities like Sao Paulo can be reviewed for budget-focused or upsell opportunities 🚨

# %%
# Cell No - 39
# Chart - 24: Age Distribution
plt.figure(figsize=(8,5))
sns.histplot(users['age'], bins=30, kde=True, color='blue')
plt.title("User Age Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a histogram with KDE line is used because age is a continuous variable and we need to understand its distribution 📊
# * it helps in visualizing how users are spread across different age groups
# * the KDE line provides a smooth view of density and patterns ✈️
# * this chart is ideal for identifying dominant age groups and overall user demographics

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * user ages are distributed broadly between 20 and 65, showing diverse customer base ✈️
# * the 36–50 age group has the highest user count, making middle-aged users an important segment 💰
# * slight peaks around 30–35 and 45–50 suggest key active age groups 📊
# * fewer users exist at very young (20–25) and older (60+) ranges 📉
# * distribution is fairly balanced without extreme skewness

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps in targeting marketing campaigns towards dominant middle-age groups 🎯
# * businesses can design travel packages suited for working professionals 💼
# * balanced distribution allows targeting multiple age segments ✨
# * low presence of younger and older users may indicate untapped market segments ⚠️
# * ignoring these segments may result in missed growth opportunities 🚨

# %%
# Cell No - 40
# Chart - 25: Gender Distribution
gender_counts = users['gender'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a pie chart is used because we are showing proportion of categories (gender distribution) 📊
# * it clearly represents percentage share of each group in the dataset
# * easy to understand overall composition at a glance ✈️
# * this chart is ideal for part-to-whole comparison

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * gender distribution is almost evenly split among male (33.7%), female (33.4%), and none (32.8%) ✈️
# * no single gender dominates the dataset, showing balanced representation 📊
# * very small differences between categories indicate uniform distribution 💰

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * balanced gender distribution allows businesses to design inclusive marketing strategies 🎯
# * no need to heavily bias campaigns toward one gender group 💼
# * equal representation supports broader customer targeting ✨
# * lack of dominant segment may make targeted campaigns less effective ⚠️
# * generic strategies may reduce personalization impact and engagement 🚨

# %%
# Cell No - 41
# Chart - 26: Age Group vs User Count
users['age_group'] = pd.cut(users['age'], bins=[18,25,35,50,70], labels=['18-25','26-35','36-50','50+'])

age_group_count = users['age_group'].value_counts()

plt.figure(figsize=(8,5))
age_group_count.plot(kind='bar', color='purple')
plt.title("User Count by Age Group")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing user counts across different age groups 📊
# * it clearly shows which age group has more or fewer users
# * bar heights make ranking and comparison very easy ✈️
# * this chart is ideal for categorical distribution analysis

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * age group 36–50 has the highest number of users, making it the dominant segment 💰
# * 50+ is also a strong segment with slightly lower count 📊
# * 26–35 has moderate representation ✈️
# * 18–25 has the lowest number of users, indicating weak presence 📉
# * user base is skewed towards older age groups

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps focus marketing efforts on dominant age group (36–50) for higher conversions 🎯
# * businesses can design premium and comfort-focused packages for older users 💼
# * strong presence of 50+ users opens opportunity for luxury travel offerings ✨
# * low presence of younger users (18–25) indicates missed growth opportunity ⚠️
# * ignoring younger segment may limit long-term customer base expansion 🚨

# %%
# Cell No - 42
# Chart - 27: Total Travel Spend per User
flight_spend = flights.groupby('userCode')['price'].sum()
hotel_spend = hotels.groupby('userCode')['total'].sum()

total_spend = pd.concat([flight_spend, hotel_spend], axis=1).fillna(0)
total_spend.columns = ['flight_spend', 'hotel_spend']
total_spend['total'] = total_spend.sum(axis=1)

plt.figure(figsize=(8,5))
sns.histplot(total_spend['total'], bins=30, kde=True, color='green')
plt.title("Total Travel Spend per User")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a histogram with KDE line is used because total travel spend per user is a continuous variable 📊
# * it helps in understanding how user spending is distributed across different ranges
# * the KDE line highlights spending patterns and density clearly ✈️
# * this chart is ideal for identifying customer segments based on spending behavior

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * total travel spend varies widely from near 0 up to around 480000 💰
# * most users are concentrated in mid-spending ranges between 100000 and 350000 📊
# * multiple peaks indicate different spending segments (low, mid, high spenders) ✈️
# * very high spenders (above 400000) are fewer, representing premium users 📉
# * distribution shows slight right skewness with presence of high-value outliers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps segment users into different spending categories for targeted marketing 🎯
# * businesses can focus on mid-spenders to maximize consistent revenue 💼
# * high spenders can be targeted with premium services and loyalty programs ✨
# * low spend users may reduce overall profitability if not upsold ⚠️
# * ignoring high-value users may lead to loss of major revenue opportunities 🚨

# %%
# Cell No - 43
# Chart - 28: Gender vs Avg Total Spend
total_spend_reset = total_spend.reset_index()
merged = total_spend_reset.merge(users, left_on='userCode', right_on='code')

plt.figure(figsize=(8,5))
sns.barplot(data=merged, x='gender', y='total', palette='coolwarm')
plt.title("Gender vs Avg Travel Spend")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing average travel spend across gender categories 📊
# * it clearly shows differences (or similarities) between groups in a simple way
# * error bars help indicate variation and reliability of the averages ✈️
# * this chart is ideal for category-wise comparison of average values

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * average travel spend is almost equal across male, female, and none categories 💰
# * all groups spend around 210000–215000, showing very small difference 📊
# * no gender group stands out as significantly higher or lower spender ✈️
# * variation within groups is also similar, indicating consistent behavior

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this shows gender does not significantly impact spending behavior 🎯
# * businesses can design neutral pricing and marketing strategies 💼
# * equal spending across groups supports inclusive targeting ✨
# * lack of differentiation reduces ability to personalize offers by gender ⚠️
# * generic strategies may limit effectiveness of targeted campaigns 🚨

# %%
# Cell No - 44
# Chart - 29: Age vs Total Spend
plt.figure(figsize=(8,5))
sns.regplot(data=merged, x='age', y='total', scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title("Age vs Total Travel Spend")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a scatter plot with trendline is used because we are analyzing relationship between age and total travel spend 📊
# * scatter points show actual distribution while trendline shows overall direction clearly
# * it helps in identifying whether age influences spending behavior ✈️
# * this chart is ideal for detecting correlation, patterns, and variability

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * the trendline is almost flat, indicating very weak or no relationship between age and total spend ✈️
# * users across all age groups (20–65) show similar spending patterns 💰
# * spending values are widely spread at all ages, showing high variability 📊
# * no specific age group consistently spends more or less than others 📉

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this shows age is not a strong factor for predicting spending behavior 🎯
# * businesses should focus on other factors like preferences or travel type 💼
# * allows creation of broad strategies instead of age-based targeting ✨
# * lack of age-based differentiation limits personalized marketing ⚠️
# * relying on age for targeting may lead to ineffective campaigns and wasted resources 🚨

# %%
# Cell No - 45
# Chart - 30: Routes by Total Flight Spend

# flight spend per route
route_spend = flights.groupby(['from','to'])['price'].sum().reset_index()
route_spend['route'] = route_spend['from'] + " → " + route_spend['to']

top_routes_spend = route_spend.sort_values(by='price', ascending=False).head(10)

plt.figure(figsize=(10,5))
sns.barplot(data=top_routes_spend, x='route', y='price', palette='viridis')
plt.title("Top 10 Routes by Total Flight Spend")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing total flight spend across different routes 📊
# * it clearly ranks routes from highest to lowest revenue contribution
# * bar height makes comparison and dominance easy to understand ✈️
# * this chart is ideal for identifying top-performing routes

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Florianopolis ↔ Aracaju routes generate the highest total spend 💰
# * multiple top routes involve Florianopolis, showing it as a key revenue hub ✈️
# * other strong routes include connections with Sao Paulo, Brasilia, and Recife 📊
# * revenue distribution is fairly close among top routes, with no extreme gap 📉

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify high-revenue routes for expansion and optimization 🎯
# * businesses can increase flight frequency on top-performing routes 💼
# * Florianopolis can be treated as a strategic hub for revenue growth ✨
# * similar revenue across routes may increase competition and reduce margins ⚠️
# * over-dependence on few routes may create risk if demand drops 🚨

# %%
# Cell No - 46
# Chart - 31: Lowest Flight Revenue Routes
route_flight = flights.groupby(['from','to'])['price'].sum().reset_index()
route_flight['route'] = route_flight['from'] + " → " + route_flight['to']

bottom_routes = route_flight.sort_values(by='price').head(10)

plt.figure(figsize=(10,5))
sns.barplot(data=bottom_routes, x='route', y='price', palette='Reds')
plt.title("Lowest Flight Revenue Routes")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing flight revenue across the lowest-performing routes 📊
# * it clearly shows which routes generate the least flight revenue
# * bar heights make it easy to rank underperforming routes ✈️
# * this chart is ideal for identifying areas needing improvement

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * routes involving Sao Paulo appear frequently among lowest revenue routes 💰
# * some routes like Salvador → Sao Paulo and Rio de Janeiro → Sao Paulo are underperforming 📉
# * revenue differences among bottom routes are relatively small, indicating uniformly low performance 📊

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify weak routes where performance improvement is needed 🎯
# * businesses can adjust pricing, promotions, or frequency on these routes 💼
# * underperforming routes can be reviewed for pricing, frequency, or promotion changes ✨
# * frequent appearance of Sao Paulo routes may indicate demand or pricing issues ⚠️
# * continuing low flight-revenue routes without review may limit revenue improvement 🚨

# %%
# Cell No - 47
# Chart - 32: Agency Revenue Performance

agency_rev = flights.groupby('agency')['price'].sum()
agency_count = flights['agency'].value_counts()

agency_df = pd.concat([agency_rev, agency_count], axis=1)
agency_df.columns = ['revenue','count']

agency_performance = agency_df.sort_values(by=['revenue','count'])

plt.figure(figsize=(10,5))
sns.barplot(x=agency_performance.index, y=agency_performance['revenue'], palette='coolwarm')
plt.title("Agency Revenue Performance")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing total revenue across agencies 📊
# * it clearly shows how agency revenue differs across the available agencies
# * bar height makes differences in revenue very easy to understand ✈️
# * this chart is ideal for performance comparison across categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * FlyingDrops has significantly lower revenue compared to other agencies 💰
# * CloudFy and Rainbow generate almost similar and very high revenue 📊
# * large gap exists between FlyingDrops and the other two agencies ✈️
# * FlyingDrops is clearly the lowest performing agency in terms of revenue 📉

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify agencies that need performance review 🎯
# * businesses can analyze why FlyingDrops has lower total revenue (pricing, routes, volume) 💼
# * strategies can be adjusted to improve revenue performance ✨
# * continued low revenue from FlyingDrops may limit overall growth if not reviewed ⚠️
# * ignoring this gap may reduce future competitiveness 🚨

# %%
# Cell No - 48
# Chart - 33: High-Distance Routes with Low Avg Price
route_stats = flights.groupby(['from','to']).agg({'distance':'mean','price':'mean'}).reset_index()
route_stats['route'] = route_stats['from'] + " → " + route_stats['to']

filtered = route_stats[(route_stats['distance'] > route_stats['distance'].median()) &
                       (route_stats['price'] < route_stats['price'].median())]

underpriced_routes = filtered.sort_values(by='distance', ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(data=underpriced_routes, x='route', y='price', palette='Blues')
plt.title("High-Distance Routes with Low Avg Price")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing average prices of high-distance routes that may be underpriced 📊
# * it clearly highlights high-distance routes in a simple and comparable way
# * bar height helps identify which routes have long distances but may not generate expected price ✈️
# * this chart is ideal for spotting routes where distance and price do not align well

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * several routes like Salvador → Brasilia and Florianopolis → Brasilia have high distances but are underpriced 💰
# * these routes should ideally have higher prices based on distance ✈️
# * multiple routes with similar long distances are not showing proportional average price 📊
# * indicates inconsistency in pricing strategy across long-distance routes 📉

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify routes where pricing can be increased to improve revenue 🎯
# * businesses can adjust pricing models to align with distance-based logic 💼
# * correcting underpricing can directly boost profitability ✨
# * continued underpricing may lead to revenue leakage and missed profit ⚠️
# * inconsistent pricing across similar routes may confuse customers and reduce trust 🚨

# %%
# Cell No - 49
# Chart - 34: Hotel Booking Count by Location
booking_by_place = hotels['place'].value_counts().sort_values()

plt.figure(figsize=(10,5))
booking_by_place.plot(kind='bar', color='grey')
plt.title("Hotel Booking Count by Location (Low to High)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing booking counts across different hotel locations 📊
# * it clearly shows which locations have the lowest bookings
# * bar height makes it easy to rank locations by booking volume ✈️
# * this chart is ideal for identifying booking demand differences across locations

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Florianopolis has the lowest hotel bookings among all locations 📉
# * Aracaju and Campo Grande also show relatively low booking counts ✈️
# * Sao Paulo appears in the lower side compared with some other locations, while Rio de Janeiro has comparatively high bookings 📊
# * differences between locations are not huge, but the lower-booking locations can be reviewed 💰

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify locations with lower booking volume for further review 🎯
# * businesses can test discounts or promotions in lower-booking areas 💼
# * marketing efforts can be focused on boosting visibility in these locations ✨
# * low bookings may reduce revenue contribution if the pattern continues ⚠️
# * ignoring these locations may leave improvement opportunities unused 🚨

# %%
# Cell No - 50
# Chart - 35: Users with Lowest Total Spend

lowest_users = total_spend.sort_values(by='total').head(10).reset_index()

plt.figure(figsize=(10,5))
sns.barplot(data=lowest_users, x='userCode', y='total', palette='viridis')
plt.title("Lowest Spending Users")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * a bar chart is used because we are comparing total spend across specific users 📊
# * it clearly highlights which users are spending the least
# * bar height makes it easy to rank users based on spending ✈️
# * this chart is ideal for identifying low-value customers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * users like 527 and 361 have the lowest spending among all 💰
# * some users in this group still show moderate spend but are lower compared to others 📊
# * variation exists within low-spending users, indicating different engagement levels ✈️
# * no user in this group shows high spending behavior 📉

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * this helps identify low-value users for targeted engagement strategies 🎯
# * businesses can offer discounts or personalized offers to increase spending 💼
# * understanding low spenders helps improve customer lifetime value ✨
# * consistently low spending users may reduce overall revenue contribution ⚠️
# * ignoring these users may result in lost opportunity to convert them into higher-value customers 🚨

# %% [markdown]
# #### Chart - 36 - Correlation Heatmap

# %%
# Cell No - 51
# Correlation Heatmap (Flights Dataset)

plt.figure(figsize=(10,6))

corr = flights_df[['price', 'time', 'distance', 'year', 'month', 'day']].corr()

sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')

plt.title("Correlation Heatmap (Flights Data)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is used to understand the strength and direction of relationships between numerical variables. It provides a quick visual summary of how different features are related to each other. 📊

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - strong positive correlation between distance and price (~0.64) 💰
# - strong correlation between time and distance (~1.00) ⏱️
# - time also shows strong correlation with price (~0.64)
# - month and day have almost no correlation with price
# - year has very weak relationship with other variables
# - overall, distance and time are the key drivers of flight price ✈️

# %% [markdown]
# #### Chart - 37 - Pair Plot

# %%
# Cell No - 52
# Pair Plot (Flights Dataset - Numerical Features)

sns.pairplot(flights_df[['price', 'time', 'distance']])

plt.suptitle("Pair Plot (Flights Data)", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is used to visualize relationships between multiple numerical variables simultaneously. It helps identify correlations, trends, and distributions in a single view. 📊

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - strong positive relationship between price, time, and distance 💰
# - time and distance show an almost perfect linear relationship (~1.00 correlation)
# - price increases as both time and distance increase
# - scatter plots show some spread, indicating influence of other factors like flight type or agency
# - distributions indicate most flights fall within mid-range values ✈️

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * focus on key middle-age customer segments, especially 36–50, as they form the largest user group 👥
#   → design targeted offers, loyalty programs, and suitable travel packages for this group
#
# * strengthen tier-based pricing strategy (economic, premium, first class) ✈️
#   → maintain clear price gaps and improve value in each tier to avoid customer confusion
#   → premium tier should be positioned clearly so customers understand its added value
#
# * implement distance + time based dynamic pricing 📊
#   → longer distance and duration flights should have optimized higher pricing
#   → reduce inconsistent pricing across similar routes
#
# * fix underpriced long-distance routes ⚠️
#   → identify routes where distance is high but price is low
#   → review pricing carefully to reduce possible revenue leakage
#
# * focus on high-demand routes and hubs ✈️
#   → Florianopolis acts as a major hub with high traffic and revenue
#   → review flight frequency, improve service quality, and optimize revenue
#
# * optimize agency-level strategy 💼
#   → CloudFy & Rainbow: continue high-volume strategy with competitive pricing
#   → FlyingDrops: improve either pricing justification or increase flight volume to stay competitive
#
# * apply seasonal pricing and demand planning 📅
#   → peak activity months (Oct–Dec) → review prices and inventory
#   → lower-activity months (mid-year) → consider discounts and promotional campaigns
#
# * optimize hotel pricing by location 🏨
#   → high-revenue cities (Recife, Salvador) → focus on premium offerings
#   → lower-booking locations → review discounts, ads, and partnerships to improve bookings
#
# * encourage longer stays 💰
#   → since total spend increases with number of days, offer “stay longer, save more” deals
#   → create packages for 3–4 day stays to maximize revenue
#
# * build bundled offerings (flight + hotel packages) 🎯
#   → users show combined spending behavior across flights and hotels
#   → bundles simplify decisions and increase total transaction value
#
# * segment users based on spending behavior 📊
#   → mid-spenders: main revenue drivers → focus on retention
#   → low-spenders: upsell with offers
#   → high-spenders: provide premium and loyalty benefits
#
# * improve low-performing routes and locations ⚠️
#   → analyze low flight-revenue routes, including some Sao Paulo connections
#   → adjust pricing, reduce frequency, or improve marketing
#
# * maintain balanced and inclusive targeting 🌍
#   → gender and age (except extremes) do not strongly affect spending
#   → focus more on behavior and preferences rather than demographics
#
# * reduce pricing inconsistencies 🚨
#   → similar routes and durations showing different prices may reduce trust
#   → standardize pricing logic to improve customer confidence
#
# * overall recommendation:
#   → move towards a system driven by dynamic pricing + route optimization + customer segmentation + bundled services
#   → this will increase revenue, improve efficiency, and create long-term scalable growth 🚀

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * this project clearly shows how data-driven analysis can transform decision-making in the travel industry 📊
#
# * strong relationship between price, distance, and time confirms that pricing should not be random but logically driven ✈️
#
# * customer behavior analysis reveals that mid-age users and mid-spenders form the core business base 💰
#
# * route, agency, and location analysis highlights that certain hubs (like Florianopolis) and cities (like Recife, Salvador) dominate revenue generation 📍
#
# * at the same time, weak routes, underpriced flights, and low-booking locations expose clear areas of revenue loss ⚠️
#
# * monthly trends indicate that travel activity is not constant, making pricing and planning important 📅
#
# * hotel and flight spending patterns show that bundled offerings and longer stays can significantly increase overall revenue 🏨
#
# * balanced gender distribution and weak age-spend correlation suggest that behavior-based targeting is more effective than demographic-based targeting 🌍
#
# * overall, the business should move towards a smart system that combines:
#   → dynamic pricing
#   → route optimization
#   → customer segmentation
#   → bundled offerings
#
# * final takeaway:
#   → companies that rely on data instead of assumptions will achieve higher efficiency, better customer experience, and sustainable growth 🚀

# %% [markdown]
# ### ***Hurrah! successfully completed EDA Capstone Project !!!***
